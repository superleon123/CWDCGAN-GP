# %%
from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)
drive.mount('/content/gdrive')
# !ls
# %cd gdrive/My\ Drive/colorectal_rgb_64/
# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# gdrive	sample_data
# /content/gdrive/My Drive/colorectal_rgb_64
# color_eval_augment._rgb.ipynb		 cwgan-gp-color_rgb.ipynb  images
# color_eval_origin_64641_ImageGene.ipynb  gan_training
# color_eval_origin_64643.ipynb		 hmnist_64_64_RGB.csv

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Mar 12 01:44:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0    29W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# importing the libraries

import numpy as np 
import pandas as pd 

# from tensorflow import keras
# # from keras.layers import Conv2D,MaxPool2D,Dense,Dropout,Flatten
# # from keras.models import Sequential
# # from keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense,Dropout,Flatten
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

#from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import confusion_matrix

# %%
#data = pd.read_csv("../input/hmnist_64_64_L.csv")      # reading the data
data = pd.read_csv("./hmnist_64_64_RGB.csv")      # reading the data

# %%
Y = data["label"]
data.drop(["label"],axis=1, inplace=True)
X = data

# %%
# creating the countplot

plt.figure(figsize=(15,7))
g = sns.countplot(Y, palette="winter_r")
plt.suptitle("Amount of each classes")
plt.show()

# %%
# it is very well balanced
Y.value_counts()
# Out:
# 4    625
# 5    625
# 1    625
# 8    625
# 6    625
# 2    625
# 3    625
# 7    625
# Name: label, dtype: int64

# %%
channel = 3
#img = X.iloc[75].as_matrix()  #old
img = X.iloc[75].to_numpy()  #leon, new
img = img.reshape(64,64,channel)
plt.imshow(img)
plt.suptitle("An example of image on the dataset")
plt.show()

# %%
# Reshaping
img_size=64
IMG_SHAPE = (64, 64, channel)
# channel = 1
# X = X.values.reshape(-1,28,28,1)       # shaping for the Keras
# Y = Y.values

# %%
# Splitting train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)
# normalize
#x_train = (x_train - 127.5) / 127.5
#x_train = x_train.astype("float32") / 255.0
x_train = np.array(x_train).reshape(-1, img_size, img_size, channel)
x_test = np.array(x_test).reshape(-1, img_size, img_size, channel)
# x_train = x_train.reshape(x_train.shape[0], *IMG_SHAPE).astype("float32")
# x_train = np.reshape(x_train, (-1, img_size, img_size, 1))

#all_digits = all_digits.astype("float32") / 255.0
# x_train = np.reshape(x_train, (-1, img_size, img_size, 1))

#label-1 to match one hot encoder
y_train = y_train - 1  
y_test = y_test - 1
#
print(y_train.value_counts())
y_train = np.array(y_train) #convert to np.array
y_test = np.array(y_test) #convert to np.array
# Out:
# 7    513
# 2    510
# 0    507
# 5    499
# 4    496
# 1    496
# 6    495
# 3    484
# Name: label, dtype: int64

# %%
print("x_train.shape: ",x_train.shape)
print("x_test.shape: ",x_test.shape)
print("y_train.shape: ",y_train.shape)
print("y_test.shape: ",y_test.shape)
# print(x_train[0:5])
# Out:
# x_train.shape:  (4000, 64, 64, 3)
# x_test.shape:  (1000, 64, 64, 3)
# y_train.shape:  (4000,)
# y_test.shape:  (1000,)

# %%
#***evaluate on origin data and augmented data together
import tensorflow as tf
from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import time
import numpy as np
from random import *
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator

# %%
# Define parameters
batch_size = 128
num_classes = 8
epochs = 50
img_rows, img_cols = 64, 64	# Input image dimensions

labels = [4]			# Reduce the 'T-shirt/Top' class

# x_train = x_train.values
# x_test = x_test.values

'''Preprocess'''

if K.image_data_format() == 'channels_first':
	x_train = x_train.reshape(x_train.shape[0], channel, img_rows, img_cols)
	x_test = x_test.reshape(x_test.shape[0], channel, img_rows, img_cols)
	input_shape = (channel, img_rows, img_cols)
else:
	x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channel)
	x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channel)
	input_shape = (img_rows, img_cols, channel)

'''
# Unbalance data
print ("Original colorectal dataset: ",x_train.shape, y_train.shape)

for label in labels:
	# Get number of samples of '6' and their indices
	indices = np.where(y_train == label)[0]
	n = len(indices)
	print ("Original number of images with ",label, ": ",n)

	# Delete a random 70% of n
	delete_index = sample(list(indices), int(0.7*n))
	x_train = np.delete(x_train, delete_index, 0)
	y_train = np.delete(y_train, delete_index, 0)

	print ("New number of images with ",label, ": ",len(np.where(y_train == label)[0]))
	print ("Now adding GAN data ...")

	# Load synthetic data
	x_gen = np.load('images/x_train_class_%d.npy' % label)

	# Normalize data
	x_gen = np.abs(x_gen)
	x_gen *= 255
	x_gen = x_gen.astype(np.uint8)
	x_gen = np.reshape(x_gen, (x_gen.shape[0], 28, 28, 1))
	
	y_gen = np.load('images/y_train_class_%d.npy' % label)
	y_gen = y_gen.astype(int)

	# Combine both datasets and shuffle
	x_train = np.concatenate((x_train, x_gen))
	y_train = np.concatenate((y_train, y_gen))
	x_train, y_train = shuffle(x_train, y_train, random_state=0)

print ("New F-MNIST: ",x_train.shape, y_train.shape)
'''

# Normalize data
x_train = x_train.astype('float32')  
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


''' Train Model '''

# Define model
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(num_classes, activation='softmax'))
###
tf.random.set_seed(42) #leon

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 8)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                verbose=1, save_best_only=True)
model = Sequential()

model.add(Conv2D(filters = 8, kernel_size = 3, padding = 'same', activation = 'relu', input_shape = input_shape))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu')) 
# model.add(Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu')) 
# model.add(Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2))

model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Dropout(0.25))
# model.add(MaxPooling2D(pool_size = 2))

# model.add(Conv2D(filters = 256, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Conv2D(filters = 256, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Dropout(0.3))
# model.add(MaxPooling2D(pool_size = 3))
# model.add(Flatten())
# model.add(Dense(128,activation = 'relu'))

model.add(GlobalMaxPooling2D())
# model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes, activation = 'softmax'))

model.summary()
####

train_datagen = ImageDataGenerator(rotation_range=20, zoom_range=0.15,
									 horizontal_flip=True, fill_mode="nearest")

# Fit model
start = time.time()
# model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
# history = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, y_test))
history = model.fit(train_datagen.flow(x_train,y_train,
                     batch_size=batch_size, 
                     seed=27,
                     shuffle=False),
                     epochs=epochs,
                     steps_per_epoch=x_train.shape[0] // batch_size,
                     validation_data=(x_test,y_test),
                     verbose=1)

# Evaluate model
end = time.time()
print ("Time: ", (end-start))

#display loss, accuracy
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs,loss, 'bo', label = 'Training loss')
plt.plot(epochs,val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

acc = history.history['accuracy'] 
val_acc = history.history['val_accuracy'] 
plt.plot(epochs, acc,'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
###

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])




Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
#y_pred = model.predict_classes(x_test)  #old version
y_pred = np.argmax(model.predict(x_test), axis=-1)  #leon, new version
print(classification_report(Y_test, y_pred))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 8)         224
#
#  dropout (Dropout)           (None, 64, 64, 8)         0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        1168
#
#  dropout_1 (Dropout)         (None, 32, 32, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        4640
#
#  dropout_2 (Dropout)         (None, 16, 16, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          18496
#
#  dropout_3 (Dropout)         (None, 8, 8, 64)          0
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 128)         73856
#
#  global_max_pooling2d (Globa  (None, 128)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 115,928
# Trainable params: 115,928
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 31/31 [==============================] - 24s 248ms/step - loss: 1.6718 - accuracy: 0.2735 - val_loss: 1.5234 - val_accuracy: 0.4790
# Epoch 2/50
# 31/31 [==============================] - 5s 169ms/step - loss: 1.1659 - accuracy: 0.5090 - val_loss: 1.4233 - val_accuracy: 0.4030
# Epoch 3/50
# 31/31 [==============================] - 5s 165ms/step - loss: 0.9671 - accuracy: 0.5927 - val_loss: 1.2205 - val_accuracy: 0.5240
# Epoch 4/50
# 31/31 [==============================] - 6s 181ms/step - loss: 0.8851 - accuracy: 0.6289 - val_loss: 1.2526 - val_accuracy: 0.4970
# Epoch 5/50
# 31/31 [==============================] - 6s 195ms/step - loss: 0.8337 - accuracy: 0.6568 - val_loss: 1.2312 - val_accuracy: 0.5370
# Epoch 6/50
# 31/31 [==============================] - 5s 163ms/step - loss: 0.7759 - accuracy: 0.6767 - val_loss: 1.3719 - val_accuracy: 0.4320
# Epoch 7/50
# 31/31 [==============================] - 7s 220ms/step - loss: 0.7377 - accuracy: 0.7076 - val_loss: 1.4606 - val_accuracy: 0.4340
# Epoch 8/50
# 31/31 [==============================] - 5s 164ms/step - loss: 0.7018 - accuracy: 0.7268 - val_loss: 1.0036 - val_accuracy: 0.6230
# Epoch 9/50
# 31/31 [==============================] - 8s 274ms/step - loss: 0.6439 - accuracy: 0.7503 - val_loss: 1.0263 - val_accuracy: 0.6130
# Epoch 10/50
# 31/31 [==============================] - 5s 164ms/step - loss: 0.6384 - accuracy: 0.7554 - val_loss: 1.1444 - val_accuracy: 0.5390
# Epoch 11/50
# 31/31 [==============================] - 5s 168ms/step - loss: 0.6170 - accuracy: 0.7576 - val_loss: 1.0653 - val_accuracy: 0.5880
# Epoch 12/50
# 31/31 [==============================] - 5s 163ms/step - loss: 0.6296 - accuracy: 0.7459 - val_loss: 1.0440 - val_accuracy: 0.5940
# Epoch 13/50
# 31/31 [==============================] - 7s 213ms/step - loss: 0.6254 - accuracy: 0.7485 - val_loss: 1.0838 - val_accuracy: 0.5540
# Epoch 14/50
# 31/31 [==============================] - 6s 185ms/step - loss: 0.5867 - accuracy: 0.7712 - val_loss: 0.9977 - val_accuracy: 0.6370
# Epoch 15/50
# 31/31 [==============================] - 5s 166ms/step - loss: 0.5973 - accuracy: 0.7707 - val_loss: 0.9180 - val_accuracy: 0.6950
# Epoch 16/50
# 31/31 [==============================] - 7s 225ms/step - loss: 0.5796 - accuracy: 0.7704 - val_loss: 1.0378 - val_accuracy: 0.6080
# Epoch 17/50
# 31/31 [==============================] - 5s 166ms/step - loss: 0.5560 - accuracy: 0.7851 - val_loss: 0.9094 - val_accuracy: 0.6920
# Epoch 18/50
# 31/31 [==============================] - 7s 214ms/step - loss: 0.5743 - accuracy: 0.7753 - val_loss: 1.1575 - val_accuracy: 0.5400
# Epoch 19/50
# 31/31 [==============================] - 5s 177ms/step - loss: 0.5436 - accuracy: 0.7872 - val_loss: 1.0189 - val_accuracy: 0.5440
# Epoch 20/50
# 31/31 [==============================] - 5s 166ms/step - loss: 0.5108 - accuracy: 0.8071 - val_loss: 0.9358 - val_accuracy: 0.6250
# Epoch 21/50
# 31/31 [==============================] - 5s 166ms/step - loss: 0.5248 - accuracy: 0.7998 - val_loss: 0.9761 - val_accuracy: 0.6470
# Epoch 22/50
# 31/31 [==============================] - 6s 185ms/step - loss: 0.4890 - accuracy: 0.8084 - val_loss: 0.8909 - val_accuracy: 0.6780
# Epoch 23/50
# 31/31 [==============================] - 8s 267ms/step - loss: 0.5207 - accuracy: 0.7998 - val_loss: 0.8305 - val_accuracy: 0.7530
# Epoch 24/50
# 31/31 [==============================] - 5s 162ms/step - loss: 0.5513 - accuracy: 0.7828 - val_loss: 1.0193 - val_accuracy: 0.5580
# Epoch 25/50
# 31/31 [==============================] - 6s 204ms/step - loss: 0.5252 - accuracy: 0.7916 - val_loss: 0.8403 - val_accuracy: 0.7190
# Epoch 26/50
# 31/31 [==============================] - 5s 170ms/step - loss: 0.4978 - accuracy: 0.8091 - val_loss: 0.9407 - val_accuracy: 0.6380
# Epoch 27/50
# 31/31 [==============================] - 7s 218ms/step - loss: 0.4772 - accuracy: 0.8179 - val_loss: 0.9615 - val_accuracy: 0.6160
# Epoch 28/50
# 31/31 [==============================] - 5s 165ms/step - loss: 0.4558 - accuracy: 0.8221 - val_loss: 0.8649 - val_accuracy: 0.6160
# Epoch 29/50
# 31/31 [==============================] - 5s 168ms/step - loss: 0.4733 - accuracy: 0.8117 - val_loss: 0.8729 - val_accuracy: 0.6280
# Epoch 30/50
# 31/31 [==============================] - 7s 213ms/step - loss: 0.4797 - accuracy: 0.8089 - val_loss: 0.8293 - val_accuracy: 0.7360
# Epoch 31/50
# 31/31 [==============================] - 5s 165ms/step - loss: 0.4513 - accuracy: 0.8252 - val_loss: 0.8829 - val_accuracy: 0.6860
# Epoch 32/50
# 31/31 [==============================] - 5s 162ms/step - loss: 0.4230 - accuracy: 0.8339 - val_loss: 0.8945 - val_accuracy: 0.6040
# Epoch 33/50
# 31/31 [==============================] - 6s 184ms/step - loss: 0.4176 - accuracy: 0.8430 - val_loss: 0.8291 - val_accuracy: 0.6930
# Epoch 34/50
# 31/31 [==============================] - 5s 167ms/step - loss: 0.4120 - accuracy: 0.8388 - val_loss: 0.7367 - val_accuracy: 0.7690
# Epoch 35/50
# 31/31 [==============================] - 7s 218ms/step - loss: 0.4269 - accuracy: 0.8378 - val_loss: 0.8220 - val_accuracy: 0.7470
# Epoch 36/50
# 31/31 [==============================] - 5s 163ms/step - loss: 0.4383 - accuracy: 0.8246 - val_loss: 0.7968 - val_accuracy: 0.7570
# Epoch 37/50
# 31/31 [==============================] - 6s 179ms/step - loss: 0.4280 - accuracy: 0.8352 - val_loss: 0.7250 - val_accuracy: 0.7760
# Epoch 38/50
# 31/31 [==============================] - 6s 196ms/step - loss: 0.3826 - accuracy: 0.8629 - val_loss: 0.7082 - val_accuracy: 0.7700
# Epoch 39/50
# 31/31 [==============================] - 5s 165ms/step - loss: 0.3880 - accuracy: 0.8585 - val_loss: 0.7752 - val_accuracy: 0.7290
# Epoch 40/50
# 31/31 [==============================] - 5s 162ms/step - loss: 0.3787 - accuracy: 0.8551 - val_loss: 0.8015 - val_accuracy: 0.7240
# Epoch 41/50
# 31/31 [==============================] - 6s 200ms/step - loss: 0.3845 - accuracy: 0.8494 - val_loss: 0.6597 - val_accuracy: 0.8050
# Epoch 42/50
# 31/31 [==============================] - 5s 170ms/step - loss: 0.3599 - accuracy: 0.8572 - val_loss: 0.7746 - val_accuracy: 0.7240
# Epoch 43/50
# 31/31 [==============================] - 7s 220ms/step - loss: 0.3732 - accuracy: 0.8572 - val_loss: 0.7205 - val_accuracy: 0.7480
# Epoch 44/50
# 31/31 [==============================] - 5s 163ms/step - loss: 0.3695 - accuracy: 0.8580 - val_loss: 0.6764 - val_accuracy: 0.7690
# Epoch 45/50
# 31/31 [==============================] - 7s 218ms/step - loss: 0.3770 - accuracy: 0.8569 - val_loss: 0.7004 - val_accuracy: 0.7620
# Epoch 46/50
# 31/31 [==============================] - 5s 168ms/step - loss: 0.3679 - accuracy: 0.8577 - val_loss: 0.6718 - val_accuracy: 0.7940
# Epoch 47/50
# 31/31 [==============================] - 7s 215ms/step - loss: 0.3627 - accuracy: 0.8675 - val_loss: 0.6591 - val_accuracy: 0.7870
# Epoch 48/50
# 31/31 [==============================] - 5s 162ms/step - loss: 0.3280 - accuracy: 0.8732 - val_loss: 0.6681 - val_accuracy: 0.7800
# Epoch 49/50
# 31/31 [==============================] - 5s 171ms/step - loss: 0.3568 - accuracy: 0.8629 - val_loss: 0.6295 - val_accuracy: 0.8030
# Epoch 50/50
# 31/31 [==============================] - 7s 209ms/step - loss: 0.3575 - accuracy: 0.8608 - val_loss: 0.7300 - val_accuracy: 0.7480
# Time:  397.0956597328186
# Test loss: 0.7300350666046143
# Test accuracy: 0.7480000257492065
# 32/32 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87       118
#            1       0.66      0.38      0.48       129
#            2       0.46      0.63      0.53       115
#            3       0.81      0.98      0.89       141
#            4       0.63      0.42      0.50       129
#            5       0.73      0.89      0.80       126
#            6       0.95      0.80      0.87       130
#            7       0.95      0.95      0.95       112
#
#     accuracy                           0.75      1000
#    macro avg       0.75      0.75      0.74      1000
# weighted avg       0.75      0.75      0.74      1000

# %%
from sklearn.metrics import ConfusionMatrixDisplay
class_names_num = ['0', '1', '2', '3', '4', '5', '6', '7']
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names_num)
disp.plot()
_ = disp.ax_.set_title("CNN")
plt.show()
