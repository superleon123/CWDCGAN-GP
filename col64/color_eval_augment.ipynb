# %%
from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)
drive.mount('/content/gdrive')
# !ls
# %cd gdrive/My\ Drive/colorectal_64/
# !ls
# Out:
# Mounted at /content/gdrive
# gdrive	sample_data
# /content/gdrive/My Drive/colorectal_64
# color_eval_augment.ipynb		 displayGeneratedImage_64641.ipynb
# color_eval_origin_64641_ImageGene.ipynb  gan_training
# color_eval_origin_64641.ipynb		 hmnist_64_64_L.csv
# color_eval_origin_64641.ipynb（副本）	 images
# cwgan-gp-color_64641.ipynb		 model_64_64_1.png

# %%
# !nvidia-smi
# Out:
# Tue Apr  4 02:32:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# importing the libraries

import numpy as np 
import pandas as pd 

# from tensorflow import keras
# # from keras.layers import Conv2D,MaxPool2D,Dense,Dropout,Flatten
# # from keras.models import Sequential
# # from keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense,Dropout,Flatten
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

#from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import confusion_matrix

# %%
#data = pd.read_csv("../input/hmnist_64_64_L.csv")      # reading the data
data = pd.read_csv("./hmnist_64_64_L.csv")      # reading the data

# %%
Y = data["label"]
data.drop(["label"],axis=1, inplace=True)
X = data

# %%
# creating the countplot

plt.figure(figsize=(15,7))
g = sns.countplot(Y, palette="winter_r")
plt.suptitle("Amount of each classes")
plt.show()

# %%
# it is very well balanced
Y.value_counts()
# Out:
# 2    625
# 5    625
# 7    625
# 6    625
# 8    625
# 1    625
# 4    625
# 3    625
# Name: label, dtype: int64

# %%
#img = X.iloc[75].as_matrix()  #old
img = X.iloc[75].to_numpy()  #leon, new
img = img.reshape(64,64,1)
plt.imshow(img)
plt.suptitle("An example of image on the dataset")
plt.show()

# %%
# Reshaping
img_size=64
IMG_SHAPE = (64, 64, 1)
channel=1
# X = X.values.reshape(-1,28,28,1)       # shaping for the Keras
# Y = Y.values

# %%
 # Splitting train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)
# normalize
#x_train = (x_train - 127.5) / 127.5
#x_train = x_train.astype("float32") / 255.0
x_train = np.array(x_train).reshape(-1, img_size, img_size, channel)
x_test = np.array(x_test).reshape(-1, img_size, img_size, channel)
# x_train = x_train.reshape(x_train.shape[0], *IMG_SHAPE).astype("float32")
# x_train = np.reshape(x_train, (-1, img_size, img_size, 1))

#all_digits = all_digits.astype("float32") / 255.0
# x_train = np.reshape(x_train, (-1, img_size, img_size, 1))

#label-1 to match one hot encoder
y_train = y_train - 1  
y_test = y_test - 1
#
print(y_train.value_counts())
y_train = np.array(y_train) #convert to np.array
y_test = np.array(y_test)
# Out:
# 5    513
# 3    510
# 6    507
# 7    499
# 4    496
# 0    496
# 2    495
# 1    484
# Name: label, dtype: int64

# %%
print("x_train.shape: ",x_train.shape)
print("x_test.shape: ",x_test.shape)
print("y_train.shape: ",y_train.shape)
print("y_test.shape: ",y_test.shape)
# print(x_train[0:5])
# Out:
# x_train.shape:  (4000, 64, 64, 1)
# x_test.shape:  (1000, 64, 64, 1)
# y_train.shape:  (4000,)
# y_test.shape:  (1000,)

# %%
#***evaluate on origin data and augmented data together
from tensorflow import keras
import tensorflow as tf
#from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import time
import numpy as np
from random import *
from sklearn.utils import shuffle
from sklearn.metrics import classification_report

from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
#from tensorflow import set_random_seed

# %%
# Define parameters
batch_size = 128
num_classes = 8
epochs = 50
img_rows, img_cols = 64, 64	# Input image dimensions
# channel = 1
labels = [4]			#  class 5

# x_train = x_train.values
# x_test = x_test.values

'''Preprocess'''

if K.image_data_format() == 'channels_first':
	x_train = x_train.reshape(x_train.shape[0], channel, img_rows, img_cols)
	x_test = x_test.reshape(x_test.shape[0], channel, img_rows, img_cols)
	input_shape = (channel, img_rows, img_cols)
else:
	x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channel)
	x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channel)
	input_shape = (img_rows, img_cols, channel)


# Unbalance data
print ("Original colorectal dataset: ",x_train.shape, y_train.shape)

for label in labels:
	# Get number of samples of '6' and their indices
	indices = np.where(y_train == label)[0]
	n = len(indices)
	print ("Original number of images with ",label, ": ",n)
	'''
	# Delete a random 50% of n
	delete_index = sample(list(indices), int(0.5*n))
	x_train = np.delete(x_train, delete_index, 0)
	y_train = np.delete(y_train, delete_index, 0)
	'''
	print ("New number of images with ",label, ": ",len(np.where(y_train == label)[0]))
	print ("Now adding GAN data ...")

	# Load synthetic data
	x_gen = np.load('images/x_train_class_%d.npy' % label)

	# Normalize data
	x_gen = np.abs(x_gen)
	x_gen *= 255
	x_gen = x_gen.astype(np.uint8)
	x_gen = np.reshape(x_gen, (x_gen.shape[0], img_rows, img_cols, channel))
	
	y_gen = np.load('images/y_train_class_%d.npy' % label)
	y_gen = y_gen.astype(int)

	# Combine both datasets and shuffle
	x_train = np.concatenate((x_train, x_gen))
	y_train = np.concatenate((y_train, y_gen))
	x_train, y_train = shuffle(x_train, y_train, random_state=0)

print ("New colorectal: ",x_train.shape, y_train.shape)
# Normalize data
x_train = x_train.astype('float32')  
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


''' Train Model '''

# # Define model  #old
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(num_classes, activation='softmax'))
# ###

#new trained model code
# set_random_seed(42)
tf.random.set_seed(42) #leon

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 8)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                verbose=1, save_best_only=True)
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu', input_shape = input_shape))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu')) 
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2))

model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2))

model.add(Conv2D(filters = 256, kernel_size = 3, padding = 'same', activation = 'relu'))
# model.add(Dropout(0.25))
# model.add(MaxPooling2D(pool_size = 2))

model.add(GlobalMaxPooling2D())
# model.add(Dense(128,activation = 'relu'))
model.add(Dense(num_classes, activation = 'softmax'))

model.summary()
####

# Fit model
start = time.time()
# model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# model.fit(train_tensors, train_targets, 
#           validation_data=(val_tensors, val_targets),
#           epochs=epochs, batch_size=20, verbose=1, callbacks = [early_stopping, checkpointer])
# model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1,callbacks = [early_stopping, checkpointer])
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Evaluate model
end = time.time()
print ("Time: ", (start-end))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#display loss, accuracy
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs,loss, 'bo', label = 'Training loss')
plt.plot(epochs,val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

acc = history.history['accuracy'] 
val_acc = history.history['val_accuracy'] 
plt.plot(epochs, acc,'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
###

Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
#y_pred = model.predict_classes(x_test)  #old version
y_pred = np.argmax(model.predict(x_test), axis=-1)  #leon, new version
print(classification_report(Y_test, y_pred))
# Out:
# Original colorectal dataset:  (4000, 64, 64, 1) (4000,)
# Original number of images with  4 :  496
# New number of images with  4 :  496
# Now adding GAN data ...
# New colorectal:  (4250, 64, 64, 1) (4250,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 16)        160
#
#  dropout (Dropout)           (None, 64, 64, 16)        0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  dropout_1 (Dropout)         (None, 32, 32, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_2 (Dropout)         (None, 16, 16, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         73856
#
#  dropout_3 (Dropout)         (None, 8, 8, 128)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 256)         295168
#
#  global_max_pooling2d (Globa  (None, 256)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 8)                 2056
#
# =================================================================
# Total params: 394,376
# Trainable params: 394,376
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 34/34 [==============================] - 19s 68ms/step - loss: 1.4791 - accuracy: 0.3816 - val_loss: 1.6027 - val_accuracy: 0.3340
# Epoch 2/50
# 34/34 [==============================] - 1s 20ms/step - loss: 1.0900 - accuracy: 0.5466 - val_loss: 1.2994 - val_accuracy: 0.4820
# Epoch 3/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.9212 - accuracy: 0.6440 - val_loss: 1.2257 - val_accuracy: 0.5310
# Epoch 4/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.8397 - accuracy: 0.6889 - val_loss: 1.2252 - val_accuracy: 0.4700
# Epoch 5/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.7852 - accuracy: 0.7064 - val_loss: 1.2467 - val_accuracy: 0.5160
# Epoch 6/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.7668 - accuracy: 0.6955 - val_loss: 1.1854 - val_accuracy: 0.4360
# Epoch 7/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.7520 - accuracy: 0.7071 - val_loss: 1.1462 - val_accuracy: 0.5800
# Epoch 8/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.7225 - accuracy: 0.7261 - val_loss: 1.0415 - val_accuracy: 0.6150
# Epoch 9/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.6560 - accuracy: 0.7496 - val_loss: 1.0756 - val_accuracy: 0.5840
# Epoch 10/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.6363 - accuracy: 0.7652 - val_loss: 1.0114 - val_accuracy: 0.6420
# Epoch 11/50
# 34/34 [==============================] - 1s 20ms/step - loss: 0.6043 - accuracy: 0.7680 - val_loss: 0.9789 - val_accuracy: 0.6400
# Epoch 12/50
# 34/34 [==============================] - 1s 20ms/step - loss: 0.5939 - accuracy: 0.7642 - val_loss: 0.9959 - val_accuracy: 0.6480
# Epoch 13/50
# 34/34 [==============================] - 1s 20ms/step - loss: 0.5243 - accuracy: 0.8035 - val_loss: 0.9831 - val_accuracy: 0.6460
# Epoch 14/50
# 34/34 [==============================] - 1s 20ms/step - loss: 0.5370 - accuracy: 0.8047 - val_loss: 0.9113 - val_accuracy: 0.6730
# Epoch 15/50
# 34/34 [==============================] - 1s 20ms/step - loss: 0.4683 - accuracy: 0.8254 - val_loss: 0.9019 - val_accuracy: 0.6270
# Epoch 16/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.4940 - accuracy: 0.8108 - val_loss: 0.9255 - val_accuracy: 0.6700
# Epoch 17/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.5234 - accuracy: 0.7896 - val_loss: 0.9384 - val_accuracy: 0.6330
# Epoch 18/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.4295 - accuracy: 0.8344 - val_loss: 0.9125 - val_accuracy: 0.5730
# Epoch 19/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3982 - accuracy: 0.8555 - val_loss: 1.1575 - val_accuracy: 0.5030
# Epoch 20/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.4648 - accuracy: 0.8158 - val_loss: 1.1583 - val_accuracy: 0.4950
# Epoch 21/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.4586 - accuracy: 0.8268 - val_loss: 0.9497 - val_accuracy: 0.6510
# Epoch 22/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3713 - accuracy: 0.8654 - val_loss: 0.9122 - val_accuracy: 0.6660
# Epoch 23/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3615 - accuracy: 0.8694 - val_loss: 0.7556 - val_accuracy: 0.7390
# Epoch 24/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3160 - accuracy: 0.8835 - val_loss: 0.6876 - val_accuracy: 0.7430
# Epoch 25/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.3264 - accuracy: 0.8751 - val_loss: 0.8770 - val_accuracy: 0.6590
# Epoch 26/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.3070 - accuracy: 0.8875 - val_loss: 0.9576 - val_accuracy: 0.6360
# Epoch 27/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2915 - accuracy: 0.8972 - val_loss: 0.8073 - val_accuracy: 0.7060
# Epoch 28/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2559 - accuracy: 0.9073 - val_loss: 0.9865 - val_accuracy: 0.6430
# Epoch 29/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2549 - accuracy: 0.9085 - val_loss: 0.8462 - val_accuracy: 0.6120
# Epoch 30/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2324 - accuracy: 0.9181 - val_loss: 0.7686 - val_accuracy: 0.7280
# Epoch 31/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.2163 - accuracy: 0.9221 - val_loss: 0.8473 - val_accuracy: 0.6970
# Epoch 32/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.2499 - accuracy: 0.9096 - val_loss: 0.8393 - val_accuracy: 0.6890
# Epoch 33/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.1920 - accuracy: 0.9367 - val_loss: 0.8889 - val_accuracy: 0.6180
# Epoch 34/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.1761 - accuracy: 0.9384 - val_loss: 0.6169 - val_accuracy: 0.7740
# Epoch 35/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.2901 - accuracy: 0.8972 - val_loss: 0.8530 - val_accuracy: 0.6970
# Epoch 36/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.1948 - accuracy: 0.9339 - val_loss: 0.8027 - val_accuracy: 0.7050
# Epoch 37/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.1488 - accuracy: 0.9508 - val_loss: 0.8496 - val_accuracy: 0.6990
# Epoch 38/50
# 34/34 [==============================] - 1s 19ms/step - loss: 0.1813 - accuracy: 0.9351 - val_loss: 0.9875 - val_accuracy: 0.5460
# Epoch 39/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.1422 - accuracy: 0.9558 - val_loss: 0.7625 - val_accuracy: 0.7180
# Epoch 40/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.1218 - accuracy: 0.9626 - val_loss: 1.0102 - val_accuracy: 0.6050
# Epoch 41/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.1074 - accuracy: 0.9654 - val_loss: 0.9504 - val_accuracy: 0.6080
# Epoch 42/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.1135 - accuracy: 0.9616 - val_loss: 0.7829 - val_accuracy: 0.7320
# Epoch 43/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.1011 - accuracy: 0.9692 - val_loss: 0.7346 - val_accuracy: 0.7260
# Epoch 44/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0896 - accuracy: 0.9694 - val_loss: 0.8578 - val_accuracy: 0.6890
# Epoch 45/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0868 - accuracy: 0.9736 - val_loss: 0.6748 - val_accuracy: 0.7780
# Epoch 46/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0732 - accuracy: 0.9781 - val_loss: 0.7320 - val_accuracy: 0.7560
# Epoch 47/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.0679 - accuracy: 0.9802 - val_loss: 1.0416 - val_accuracy: 0.6620
# Epoch 48/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.1453 - accuracy: 0.9496 - val_loss: 0.7286 - val_accuracy: 0.7260
# Epoch 49/50
# 34/34 [==============================] - 1s 17ms/step - loss: 0.1242 - accuracy: 0.9593 - val_loss: 0.6320 - val_accuracy: 0.7910
# Epoch 50/50
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0725 - accuracy: 0.9798 - val_loss: 0.7007 - val_accuracy: 0.7680
# Time:  -49.50008463859558
# Test loss: 0.700727641582489
# Test accuracy: 0.7680000066757202
# 32/32 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       129
#            1       0.73      0.50      0.60       141
#            2       0.51      0.88      0.65       130
#            3       0.95      0.83      0.88       115
#            4       0.59      0.58      0.58       129
#            5       0.91      0.80      0.85       112
#            6       0.98      0.73      0.83       118
#            7       0.95      0.99      0.97       126
#
#     accuracy                           0.77      1000
#    macro avg       0.81      0.77      0.78      1000
# weighted avg       0.80      0.77      0.77      1000

# %%
from sklearn.metrics import ConfusionMatrixDisplay
class_names_num = ['0', '1', '2', '3', '4', '5', '6', '7']
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names_num)
disp.plot()
_ = disp.ax_.set_title("CNN")
plt.show()
