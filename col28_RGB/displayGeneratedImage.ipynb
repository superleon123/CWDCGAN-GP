# %%
from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)
drive.mount('/content/gdrive')
# !ls
# %cd gdrive/My\ Drive/colorectal_rgb/
# !ls
# Out:
# Mounted at /content/gdrive
# gdrive	sample_data
# /content/gdrive/My Drive/colorectal_rgb
# color_eval_augment_II._rgb.ipynb	       cwgan-gp-color_rgb.ipynb
# color_eval_augment._rgb.ipynb		       displayGeneratedImage.ipynb
# color_eval_origin_28283.ipynb		       gan_training
# color_eval_origin_28283.ipynb（副本）	       hmnist_28_28_RGB.csv
# color_eval_origin_28283.ipynb（副本）（副本）  images
# color_eval_origin_ig_generator.ipynb	       model_1.png
# cwgan-gp-color_rgb_bak.ipynb

# %% [markdown]
# Load a few generated images and show them in ImageGrid

# %%
import numpy as np
import pandas as pd 
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from PIL import Image

# %%
channel = 3
label = 4
# x_gen = np.load('images/x_train_class_%d.npy' % label)
x_gen = np.load('images/x_train_class_a_%d.npy' % label)

# Normalize data
# x_gen = np.abs(x_gen)
# x_gen *= 255
# x_gen = x_gen.astype(np.uint8)
# x_gen = np.reshape(x_gen, (x_gen.shape[0], 28, 28, channel))
	
# y_gen = np.load('images/y_train_class_%d.npy' % label)
y_gen = np.load('images/y_train_class_a_%d.npy' % label)
y_gen = y_gen.astype(int)

	# Combine both datasets and shuffle
# 	x_train = np.concatenate((x_train, x_gen))
# 	y_train = np.concatenate((y_train, y_gen))
# 	x_train, y_train = shuffle(x_train, y_train, random_state=0)

# print ("New colorectal: ",x_train.shape, y_train.shape)
print ("New colorectal: ",x_gen.shape)
# print(x_gen[0:2])
# Out:
# New colorectal:  (250, 28, 28, 3)

# %%
scale = 4  # enlarge 10 times
# Normalize data
x_gen = x_gen.astype('float32')  
x_gen /= 255.0
#  x_train.astype("float32") / 255.0
# print(x_gen[0:2])
# i=100

# %%
# for i in range(5): #range(len(generated_images)-1):   # To create all required images, range(len(generatedImages)+1))
#   # img = generated_images[i].numpy()
#   # img = x_gen[i].numpy()

#   img = x_gen[i]
  
#   img = img.reshape(28,28,3)
#   # img = keras.preprocessing.image.array_to_img(img)
#   #plt.imshow(generated_images[i], cmap='gray') #leon

#   plt.imshow(x_gen[i]) #leon
  
#   plt.axis('off')
#   # plt.show()
#   plt.savefig('images/x%d.png' % i)
#   # img.save('images/x%d.png' % i)
#   image = Image.open('images/x%d.png' % i)
#   display(image.resize(( int(image.width * scale), int(image.height * scale))))

# %%
from matplotlib import image
from IPython.display import display
from PIL import Image

xx_gen = x_gen[0:10]
# xx_gen = x_gen[200:210]
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
# import numpy as np

fig = plt.figure(figsize=(10., 4.))
grid = ImageGrid(fig, 111, # similar to subplot(111)
                 nrows_ncols=(2, 5),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes
                 )

for ax, im in zip(grid, xx_gen):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)

plt.show()

# image[] = 0
# scale = 5
# for i in range(10): #range(len(generated_images)-1):   # To create all required images, range(len(generatedImages)+1))
#   # img = generated_images[i].numpy()
#   # img = keras.preprocessing.image.array_to_img(img)
#   # #plt.imshow(generated_images[i], cmap='gray') #leon
#   # plt.imshow(generated_images[i]) #leon
#   # plt.axis('off')
#   #plt.savefig('images/%d.png' % i)
#   # img.save('images/%d.png' % i)
#   image = Image.open('images/%d.png' % i)
#   display(image.resize(( int(image.width * scale), int(image.height * scale))))
#   # display(image)


fig, axs = plt.subplots(2,5, figsize=(10,4), sharey=True, sharex=True)
cnt=0
for i in range(2):
  for j in range(5):
    axs[i,j].imshow(xx_gen[i*j],cmap = 'gray')
    axs[i,j].axis('off')

# %%
import cv2
from google.colab.patches import cv2_imshow
# path
# path = r'C:\Users\Rajnish\Desktop\geeksforgeeks.png'
  
# Reading an image in default mode
# img = ndarray(img)
window_name = 'image'
xxx_gen = xx_gen
xxx_gen = np.zeros(xxx_gen.shape)
for i in range(10): #range(len(generated_images)-1):   # To create all required images, range(len(generatedImages)+1))
  image = cv2.imread(r'./images/%d.png' % i)
  # image = image.append("./images/%d.png" % i)
# Window name in which image is displayed
# Using cv2.imshow() method
# Displaying the image
  # cv2_imshow(image)
  xxx_gen[i] = image.astype("float32") / 255.0
  plt.imshow(image)
  plt.show()

# plt.axis('off')#关闭坐标轴  设置为on则表示开启坐标轴
# plt.title('陈一月')#图像标题
# plt.show()
# waits for user to press any key
# (this is necessary to avoid Python kernel form crashing)
cv2.waitKey(0)
  
# closing all open windows
cv2.destroyAllWindows()

# %%
fig = plt.figure(figsize=(10., 4.))
grid = ImageGrid(fig, 111, # similar to subplot(111)
                 nrows_ncols=(2, 5),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes
                 )

for ax, im in zip(grid, xxx_gen):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)

plt.show()

# %%
# xxx=[]
# xxx = np.ndarray(xxx)
# xxx.reshape(10,28,28,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-cecc610899e9> in <cell line: 3>()
#       1 xxx=[]
#       2 xxx = np.ndarray(xxx)
# ----> 3 xxx.reshape(10,28,28,3)
#
# ValueError: cannot reshape array of size 1 into shape (10,28,28,3)
