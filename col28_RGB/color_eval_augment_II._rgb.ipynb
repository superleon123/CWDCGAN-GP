# %%
from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)
drive.mount('/content/gdrive')
# !ls
# %cd gdrive/My\ Drive/colorectal_rgb/
# !ls
# Out:
# Mounted at /content/gdrive
# gdrive	sample_data
# /content/gdrive/My Drive/colorectal_rgb
# color_eval_augment_II._rgb.ipynb	       cwgan-gp-color_rgb.ipynb
# color_eval_augment._rgb.ipynb		       displayGeneratedImage.ipynb
# color_eval_origin_28283.ipynb		       gan_training
# color_eval_origin_28283.ipynb（副本）	       hmnist_28_28_RGB.csv
# color_eval_origin_28283.ipynb（副本）（副本）  images
# color_eval_origin_ig_generator.ipynb	       model_1.png
# cwgan-gp-color_rgb_bak.ipynb

# %%
# !nvidia-smi
# Out:
# Tue Apr  4 03:51:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# importing the libraries

import numpy as np 
import pandas as pd 

# from tensorflow import keras
# # from keras.layers import Conv2D,MaxPool2D,Dense,Dropout,Flatten
# # from keras.models import Sequential
# # from keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense,Dropout,Flatten
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

#from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import confusion_matrix

# %%
#data = pd.read_csv("../input/hmnist_64_64_L.csv")      # reading the data
data = pd.read_csv("./hmnist_28_28_RGB.csv")      # reading the data

# %%
Y = data["label"]
data.drop(["label"],axis=1, inplace=True)
X = data

# %%
# creating the countplot

plt.figure(figsize=(15,7))
g = sns.countplot(Y, palette="winter_r")
plt.suptitle("Amount of each classes")
plt.show()

# %%
# it is very well balanced
Y.value_counts()
# Out:
# 2    625
# 5    625
# 7    625
# 6    625
# 8    625
# 1    625
# 4    625
# 3    625
# Name: label, dtype: int64

# %%
#img = X.iloc[75].as_matrix()  #old
img = X.iloc[75].to_numpy()  #leon, new
img = img.reshape(28,28,3)
plt.imshow(img)
plt.suptitle("An example of image on the dataset")
plt.show()

# %%
# Reshaping
img_size=28
IMG_SHAPE = (28, 28, 3)
# X = X.values.reshape(-1,28,28,1)       # shaping for the Keras
# Y = Y.values

# %%
 # Splitting train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)
# normalize
#x_train = (x_train - 127.5) / 127.5
#x_train = x_train.astype("float32") / 255.0
x_train = np.array(x_train).reshape(-1, img_size, img_size, 3)
x_test = np.array(x_test).reshape(-1, img_size, img_size, 3)
# x_train = x_train.reshape(x_train.shape[0], *IMG_SHAPE).astype("float32")
# x_train = np.reshape(x_train, (-1, img_size, img_size, 1))

#all_digits = all_digits.astype("float32") / 255.0
# x_train = np.reshape(x_train, (-1, img_size, img_size, 1))

#label-1 to match one hot encoder
y_train = y_train - 1  
y_test = y_test - 1
#
print(y_train.value_counts())
y_train = np.array(y_train) #convert to np.array
y_test = np.array(y_test)
# Out:
# 5    513
# 3    510
# 6    507
# 7    499
# 4    496
# 0    496
# 2    495
# 1    484
# Name: label, dtype: int64

# %%
print("x_train.shape: ",x_train.shape)
print("x_test.shape: ",x_test.shape)
print("y_train.shape: ",y_train.shape)
print("y_test.shape: ",y_test.shape)
# print(x_train[0:5])
# Out:
# x_train.shape:  (4000, 28, 28, 3)
# x_test.shape:  (1000, 28, 28, 3)
# y_train.shape:  (4000,)
# y_test.shape:  (1000,)

# %%
#***evaluate on origin data and augmented data together
from tensorflow import keras
import tensorflow as tf
#from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import time
import numpy as np
from random import *
from sklearn.utils import shuffle
from sklearn.metrics import classification_report

from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
#from tensorflow import set_random_seed

# %%
# Define parameters
batch_size = 128
num_classes = 8
epochs = 50
img_rows, img_cols = 28, 28	# Input image dimensions
channel = 3
labels = [4]			#  class 5

# x_train = x_train.values
# x_test = x_test.values

'''Preprocess'''

if K.image_data_format() == 'channels_first':
	x_train = x_train.reshape(x_train.shape[0], channel, img_rows, img_cols)
	x_test = x_test.reshape(x_test.shape[0], channel, img_rows, img_cols)
	input_shape = (channel, img_rows, img_cols)
else:
	x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channel)
	x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channel)
	input_shape = (img_rows, img_cols, channel)


# Unbalance data
print ("Original colorectal dataset: ",x_train.shape, y_train.shape)

for label in labels:
	# Get number of samples of '6' and their indices
	indices = np.where(y_train == label)[0]
	n = len(indices)
	print ("Original number of images with ",label, ": ",n)
	'''
	# Delete a random 50% of n
	delete_index = sample(list(indices), int(0.5*n))
	x_train = np.delete(x_train, delete_index, 0)
	y_train = np.delete(y_train, delete_index, 0)
	'''
	print ("New number of images with ",label, ": ",len(np.where(y_train == label)[0]))
	print ("Now adding GAN data ...")

	# Load synthetic data
	x_gen = np.load('images/x_train_class_a_%d.npy' % label)

	# Normalize data
	x_gen = np.abs(x_gen)
	x_gen *= 255
	x_gen = x_gen.astype(np.uint8)
	x_gen = np.reshape(x_gen, (x_gen.shape[0], 28, 28, channel))
	
	y_gen = np.load('images/y_train_class_a_%d.npy' % label)
	y_gen = y_gen.astype(int)
	
	# Combine both datasets and shuffle
	x_train = np.concatenate((x_train, x_gen))
	y_train = np.concatenate((y_train, y_gen))
	x_train, y_train = shuffle(x_train, y_train, random_state=0)

print('y_gen label', y_gen[0:5])
# sys.exit(0)

print ("New colorectal: ",x_train.shape, y_train.shape)
# Normalize data
x_train = x_train.astype('float32')  
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)


''' Train Model '''

# # Define model  #old
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(num_classes, activation='softmax'))
# ###

#new trained model code
# set_random_seed(42)
tf.random.set_seed(42) #leon

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 8)
checkpointer = ModelCheckpoint(filepath='weights.hdf5', 
                verbose=1, save_best_only=True)
model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 3, padding = 'same', activation = 'relu', input_shape = input_shape))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu')) 
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2)) 

model.add(Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size = 2))

model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))

model.add(GlobalMaxPooling2D())
model.add(Dense(num_classes, activation = 'softmax'))

model.summary()
####

# Fit model
start = time.time()
# model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(), metrics=['accuracy'])

# model.fit(train_tensors, train_targets, 
#           validation_data=(val_tensors, val_targets),
#           epochs=epochs, batch_size=20, verbose=1, callbacks = [early_stopping, checkpointer])
# model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1,callbacks = [early_stopping, checkpointer])
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=batch_size, epochs=epochs, verbose=1)
# Evaluate model
end = time.time()
print ("Time: ", (start-end))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#display loss, accuracy
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs,loss, 'bo', label = 'Training loss')
plt.plot(epochs,val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.figure()

acc = history.history['accuracy'] 
val_acc = history.history['val_accuracy'] 
plt.plot(epochs, acc,'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()
###

Y_test = np.argmax(y_test, axis=1) # Convert one-hot to index
#y_pred = model.predict_classes(x_test)  #old version
y_pred = np.argmax(model.predict(x_test), axis=-1)  #leon, new version
print(classification_report(Y_test, y_pred))
# Out:
# Original colorectal dataset:  (4000, 28, 28, 3) (4000,)
# Original number of images with  4 :  496
# New number of images with  4 :  496
# Now adding GAN data ...
# y_gen label [4 4 4 4 4]
# New colorectal:  (4250, 28, 28, 3) (4250,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        448
#
#  dropout (Dropout)           (None, 28, 28, 16)        0
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        4640
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          18496
#
#  dropout_2 (Dropout)         (None, 7, 7, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 128)         73856
#
#  global_max_pooling2d (Globa  (None, 128)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 8)                 1032
#
# =================================================================
# Total params: 98,472
# Trainable params: 98,472
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 34/34 [==============================] - 14s 24ms/step - loss: 1.5064 - accuracy: 0.3908 - val_loss: 1.3026 - val_accuracy: 0.5320
# Epoch 2/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.9412 - accuracy: 0.6242 - val_loss: 1.0992 - val_accuracy: 0.6000
# Epoch 3/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.8223 - accuracy: 0.6661 - val_loss: 0.9756 - val_accuracy: 0.6290
# Epoch 4/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.7500 - accuracy: 0.6981 - val_loss: 0.8739 - val_accuracy: 0.7220
# Epoch 5/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.6988 - accuracy: 0.7271 - val_loss: 0.8936 - val_accuracy: 0.7030
# Epoch 6/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.6507 - accuracy: 0.7428 - val_loss: 0.8353 - val_accuracy: 0.7230
# Epoch 7/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.6482 - accuracy: 0.7435 - val_loss: 0.8765 - val_accuracy: 0.6620
# Epoch 8/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.6460 - accuracy: 0.7409 - val_loss: 0.8190 - val_accuracy: 0.7390
# Epoch 9/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.6191 - accuracy: 0.7565 - val_loss: 0.7923 - val_accuracy: 0.7280
# Epoch 10/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.5807 - accuracy: 0.7739 - val_loss: 0.7305 - val_accuracy: 0.7670
# Epoch 11/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.5886 - accuracy: 0.7668 - val_loss: 0.7589 - val_accuracy: 0.7710
# Epoch 12/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.5570 - accuracy: 0.7849 - val_loss: 0.7117 - val_accuracy: 0.7870
# Epoch 13/50
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5473 - accuracy: 0.7847 - val_loss: 0.8281 - val_accuracy: 0.6670
# Epoch 14/50
# 34/34 [==============================] - 0s 9ms/step - loss: 0.5286 - accuracy: 0.8000 - val_loss: 0.6713 - val_accuracy: 0.7960
# Epoch 15/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.5190 - accuracy: 0.7927 - val_loss: 0.7277 - val_accuracy: 0.7450
# Epoch 16/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.5538 - accuracy: 0.7835 - val_loss: 0.6721 - val_accuracy: 0.8030
# Epoch 17/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.5181 - accuracy: 0.7993 - val_loss: 0.6566 - val_accuracy: 0.7860
# Epoch 18/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.4705 - accuracy: 0.8216 - val_loss: 0.6527 - val_accuracy: 0.7880
# Epoch 19/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.4773 - accuracy: 0.8111 - val_loss: 0.6572 - val_accuracy: 0.7550
# Epoch 20/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.4993 - accuracy: 0.8094 - val_loss: 0.6346 - val_accuracy: 0.7990
# Epoch 21/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.4632 - accuracy: 0.8212 - val_loss: 0.6131 - val_accuracy: 0.7990
# Epoch 22/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.4860 - accuracy: 0.8118 - val_loss: 0.6885 - val_accuracy: 0.7700
# Epoch 23/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.5037 - accuracy: 0.7958 - val_loss: 0.6396 - val_accuracy: 0.8120
# Epoch 24/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.4264 - accuracy: 0.8426 - val_loss: 0.5909 - val_accuracy: 0.7860
# Epoch 25/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.4209 - accuracy: 0.8438 - val_loss: 0.6150 - val_accuracy: 0.7740
# Epoch 26/50
# 34/34 [==============================] - 1s 16ms/step - loss: 0.4321 - accuracy: 0.8416 - val_loss: 0.6301 - val_accuracy: 0.7710
# Epoch 27/50
# 34/34 [==============================] - 0s 12ms/step - loss: 0.4526 - accuracy: 0.8238 - val_loss: 0.5894 - val_accuracy: 0.8190
# Epoch 28/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.4076 - accuracy: 0.8527 - val_loss: 0.5966 - val_accuracy: 0.7920
# Epoch 29/50
# 34/34 [==============================] - 0s 13ms/step - loss: 0.4372 - accuracy: 0.8299 - val_loss: 0.6239 - val_accuracy: 0.8140
# Epoch 30/50
# 34/34 [==============================] - 0s 14ms/step - loss: 0.4056 - accuracy: 0.8492 - val_loss: 0.5799 - val_accuracy: 0.8010
# Epoch 31/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.3934 - accuracy: 0.8595 - val_loss: 0.5747 - val_accuracy: 0.7950
# Epoch 32/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3845 - accuracy: 0.8558 - val_loss: 0.5964 - val_accuracy: 0.8050
# Epoch 33/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3827 - accuracy: 0.8565 - val_loss: 0.5677 - val_accuracy: 0.8120
# Epoch 34/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3651 - accuracy: 0.8621 - val_loss: 0.5612 - val_accuracy: 0.7810
# Epoch 35/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3707 - accuracy: 0.8612 - val_loss: 0.5803 - val_accuracy: 0.8100
# Epoch 36/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3589 - accuracy: 0.8659 - val_loss: 0.5387 - val_accuracy: 0.8240
# Epoch 37/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3610 - accuracy: 0.8664 - val_loss: 0.5624 - val_accuracy: 0.8110
# Epoch 38/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3852 - accuracy: 0.8555 - val_loss: 0.5413 - val_accuracy: 0.8130
# Epoch 39/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3778 - accuracy: 0.8638 - val_loss: 0.5310 - val_accuracy: 0.8100
# Epoch 40/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3393 - accuracy: 0.8753 - val_loss: 0.5609 - val_accuracy: 0.8190
# Epoch 41/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3304 - accuracy: 0.8809 - val_loss: 0.6963 - val_accuracy: 0.7270
# Epoch 42/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3495 - accuracy: 0.8713 - val_loss: 0.5844 - val_accuracy: 0.7790
# Epoch 43/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3366 - accuracy: 0.8762 - val_loss: 0.5240 - val_accuracy: 0.8100
# Epoch 44/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3401 - accuracy: 0.8711 - val_loss: 0.5868 - val_accuracy: 0.7880
# Epoch 45/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.3134 - accuracy: 0.8840 - val_loss: 0.5549 - val_accuracy: 0.8140
# Epoch 46/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3057 - accuracy: 0.8929 - val_loss: 0.5024 - val_accuracy: 0.8110
# Epoch 47/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3126 - accuracy: 0.8845 - val_loss: 0.5829 - val_accuracy: 0.8090
# Epoch 48/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.3297 - accuracy: 0.8701 - val_loss: 0.5705 - val_accuracy: 0.7950
# Epoch 49/50
# 34/34 [==============================] - 0s 8ms/step - loss: 0.2996 - accuracy: 0.8908 - val_loss: 0.5001 - val_accuracy: 0.8210
# Epoch 50/50
# 34/34 [==============================] - 0s 7ms/step - loss: 0.2930 - accuracy: 0.8953 - val_loss: 0.5519 - val_accuracy: 0.7990
# Time:  -42.30071663856506
# Test loss: 0.5519384145736694
# Test accuracy: 0.7990000247955322
# 32/32 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80       129
#            1       0.70      0.70      0.70       141
#            2       0.88      0.49      0.63       130
#            3       0.96      0.82      0.88       115
#            4       0.68      0.81      0.74       129
#            5       0.74      0.88      0.81       112
#            6       0.96      0.83      0.89       118
#            7       0.88      1.00      0.94       126
#
#     accuracy                           0.80      1000
#    macro avg       0.82      0.80      0.80      1000
# weighted avg       0.81      0.80      0.80      1000

# %%
from sklearn.metrics import ConfusionMatrixDisplay
class_names_num = ['0', '1', '2', '3', '4', '5', '6', '7']
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names_num)
disp.plot()
_ = disp.ax_.set_title("CNN")
plt.show()
